# %%
import numpy as np

# Transition matrix
P = np.array([
    [0.8, 0.2, 0.0],
    [0.4, 0.4, 0.2],
    [0.2, 0.6, 0.2]
])

# Initial beliefs as row vectors
bel_0_1 = np.array([1.0, 0.0, 0.0])  # sunny
bel_0_2 = np.array([0.0, 1.0, 0.0])  # cloudy
bel_0_3 = np.array([0.0, 0.0, 1.0])  # rainy

# Number of steps
t = 3

# Compute P^t
P_t = np.linalg.matrix_power(P, t)

# Compute beliefs at step t
bel_t_1 = bel_0_1 @ P_t
bel_t_2 = bel_0_2 @ P_t
bel_t_3 = bel_0_3 @ P_t

print()

print("Belief at step" ,t, "starting from sunny:", bel_t_1)
print("Belief at step" ,t, "starting from cloudy:", bel_t_2)
print("Belief at step" ,t, "starting from rainy:", bel_t_3)
# Out:
# Belief at step 3 starting from sunny: [0.68  0.264 0.056]
# Belief at step 3 starting from cloudy: [0.584 0.32  0.096]
# Belief at step 3 starting from rainy: [0.544 0.344 0.112]
